# %% [markdown]
# # Summer Olympics Data Analysis Assignment

# %% [markdown]
# ### 1. In how many cities Summer Olympics is held so far?

# %%
import pandas as pd

# %%
df = pd.read_csv('/home/nithish/Downloads/summer.csv')

# %%
df['City'].count()
# Out:
# 31165

# %% [markdown]
# ### 2. Which sport is having most number of Gold Medals so far? (Top 5)

# %%
df1 = df[df['Medal']=='Gold']

# %%
df1
# Out:
#        Year    City      Sport           Discipline  \
# 0      1896  Athens   Aquatics             Swimming
# 3      1896  Athens   Aquatics             Swimming
# 6      1896  Athens   Aquatics             Swimming
# 9      1896  Athens   Aquatics             Swimming
# 13     1896  Athens  Athletics            Athletics
# ...     ...     ...        ...                  ...
# 31145  2012  London  Wrestling  Wrestling Freestyle
# 31149  2012  London  Wrestling  Wrestling Freestyle
# 31153  2012  London  Wrestling  Wrestling Freestyle
# 31157  2012  London  Wrestling  Wrestling Freestyle
# 31161  2012  London  Wrestling  Wrestling Freestyle
#
#                          Athlete Country Gender                       Event  \
# 0                  HAJOS, Alfred     HUN    Men              100M Freestyle
# 3             MALOKINIS, Ioannis     GRE    Men  100M Freestyle For Sailors
# 6                  HAJOS, Alfred     HUN    Men             1200M Freestyle
# ...

# %%
x = df1.drop(['Year','City','Discipline','Athlete','Country','Gender','Event'], axis = 1)

# %%
x
# Out:
#            Sport Medal
# 0       Aquatics  Gold
# 3       Aquatics  Gold
# 6       Aquatics  Gold
# 9       Aquatics  Gold
# 13     Athletics  Gold
# ...          ...   ...
# 31145  Wrestling  Gold
# 31149  Wrestling  Gold
# 31153  Wrestling  Gold
# 31157  Wrestling  Gold
# 31161  Wrestling  Gold
#
# [10486 rows x 2 columns]

# %%
y = x['Sport'].value_counts().head()

# %%
y
# Out:
# Aquatics      1421
# Athletics     1215
# Rowing         890
# Gymnastics     820
# Fencing        552
# Name: Sport, dtype: int64

# %%
import matplotlib.pyplot as plt
plt.plot(y)
plt.xlabel('x - axis')
plt.ylabel('y - axis')
plt.title('Sports having most number of Gold medals so far')
plt.show()

# %% [markdown]
# ### 3. Which sport is having most number of medals so far? (Top 5)

# %%
x1 = df.drop(['Year','City','Discipline','Athlete','Country','Gender','Event'], axis = 1)

# %%
x1
# Out:
#            Sport   Medal
# 0       Aquatics    Gold
# 1       Aquatics  Silver
# 2       Aquatics  Bronze
# 3       Aquatics    Gold
# 4       Aquatics  Silver
# ...          ...     ...
# 31160  Wrestling  Bronze
# 31161  Wrestling    Gold
# 31162  Wrestling  Silver
# 31163  Wrestling  Bronze
# 31164  Wrestling  Bronze
#
# [31165 rows x 2 columns]

# %%
y1 = x1['Sport'].value_counts().head()

# %%
plt.plot(y1)
plt.xlabel('x - axis')
plt.ylabel('y - axis')
plt.title('Sport having most number of medals so far')
plt.show()

# %% [markdown]
# ### 4. Which player has won most number of medals? (Top 5)

# %%
x2 = df.drop(['Year','City','Sport','Discipline','Country','Gender','Event'], axis = 1)

# %%
x2
# Out:
#                          Athlete   Medal
# 0                  HAJOS, Alfred    Gold
# 1               HERSCHMANN, Otto  Silver
# 2              DRIVAS, Dimitrios  Bronze
# 3             MALOKINIS, Ioannis    Gold
# 4             CHASAPIS, Spiridon  Silver
# ...                          ...     ...
# 31160         JANIKOWSKI, Damian  Bronze
# 31161  REZAEI, Ghasem Gholamreza    Gold
# 31162             TOTROV, Rustam  Silver
# 31163          ALEKSANYAN, Artur  Bronze
# 31164             LIDBERG, Jimmy  Bronze
#
# [31165 rows x 2 columns]

# %%
y2 = x2['Athlete'].value_counts().head()

# %%
y2
# Out:
# PHELPS, Michael         22
# LATYNINA, Larisa        18
# ANDRIANOV, Nikolay      15
# SHAKHLIN, Boris         13
# MANGIAROTTI, Edoardo    13
# Name: Athlete, dtype: int64

# %%
plt.plot(y2)
plt.xlabel('x - axis')
plt.ylabel('y - axis')
plt.title('Player having most number of medals so far')
plt.show()

# %% [markdown]
# ### 5. Which player has won most number Gold Medals of medals? (Top 5)

# %%
x3 = df1.drop(['Year','City','Sport','Discipline','Country','Gender','Event'], axis = 1)

# %%
x3
# Out:
#                          Athlete Medal
# 0                  HAJOS, Alfred  Gold
# 3             MALOKINIS, Ioannis  Gold
# 6                  HAJOS, Alfred  Gold
# 9                  NEUMANN, Paul  Gold
# 13                 BURKE, Thomas  Gold
# ...                          ...   ...
# 31145         NOROOZI, Omid Haji  Gold
# 31149              KIM, Hyeonwoo  Gold
# 31153              VLASOV, Roman  Gold
# 31157              KHUGAEV, Alan  Gold
# 31161  REZAEI, Ghasem Gholamreza  Gold
#
# [10486 rows x 2 columns]

# %%
y3 = df1['Athlete'].value_counts().head()

# %%
y3
# Out:
# PHELPS, Michael     18
# NURMI, Paavo         9
# LEWIS, Carl          9
# SPITZ, Mark          9
# LATYNINA, Larisa     9
# Name: Athlete, dtype: int64

# %%
plt.plot(y3)
plt.xlabel('x - axis')
plt.ylabel('y - axis')
plt.title('Player having most number of Gold medals so far')
plt.show()

# %% [markdown]
# ### 6. In which year India won first Gold Medal in Summer Olympics?

# %%
x4 = df1[df1['Country']== 'IND'].head()

# %%
x4
# Out:
#       Year       City   Sport Discipline                       Athlete  \
# 5512  1928  Amsterdam  Hockey     Hockey          ALLEN, Richard James
# 5513  1928  Amsterdam  Hockey     Hockey                   CHAND, Dyan
# 5514  1928  Amsterdam  Hockey     Hockey           GATELEY, Maurice A.
# 5515  1928  Amsterdam  Hockey     Hockey                   GILL, K. S.
# 5516  1928  Amsterdam  Hockey     Hockey  GOODSIR-CULLEN, William John
#
#      Country Gender   Event Medal
# 5512     IND    Men  Hockey  Gold
# 5513     IND    Men  Hockey  Gold
# 5514     IND    Men  Hockey  Gold
# 5515     IND    Men  Hockey  Gold
# 5516     IND    Men  Hockey  Gold

# %%
y4 = df1[df1['Country']== 'IND'].head(1)

# %%
y4
# Out:
#       Year       City   Sport Discipline               Athlete Country Gender  \
# 5512  1928  Amsterdam  Hockey     Hockey  ALLEN, Richard James     IND    Men
#
#        Event Medal
# 5512  Hockey  Gold

# %%
y4['Year']
# Out:
# 5512    1928
# Name: Year, dtype: int64

# %% [markdown]
# ### 7. Which event is most popular in terms on number of players? (Top 5)

# %%
x5 = df.drop(['Year','City','Sport','Discipline','Country','Gender','Medal'], axis = 1)

# %%
x5
# Out:
#                          Athlete                       Event
# 0                  HAJOS, Alfred              100M Freestyle
# 1               HERSCHMANN, Otto              100M Freestyle
# 2              DRIVAS, Dimitrios  100M Freestyle For Sailors
# 3             MALOKINIS, Ioannis  100M Freestyle For Sailors
# 4             CHASAPIS, Spiridon  100M Freestyle For Sailors
# ...                          ...                         ...
# 31160         JANIKOWSKI, Damian                    Wg 84 KG
# 31161  REZAEI, Ghasem Gholamreza                    Wg 96 KG
# 31162             TOTROV, Rustam                    Wg 96 KG
# 31163          ALEKSANYAN, Artur                    Wg 96 KG
# 31164             LIDBERG, Jimmy                    Wg 96 KG
#
# [31165 rows x 2 columns]

# %%
d = df.groupby(['Event'], sort=False, as_index=False)['Athlete'].count()

# %%
d
# Out:
#                           Event  Athlete
# 0                100M Freestyle      148
# 1    100M Freestyle For Sailors        3
# 2               1200M Freestyle        3
# 3                400M Freestyle      144
# 4                          100M      142
# ..                          ...      ...
# 661                    Wg 60 KG        4
# 662                    Wg 66 KG        4
# 663                    Wg 74 KG        4
# 664                    Wg 84 KG        4
# 665                    Wg 96 KG        4
#
# [666 rows x 2 columns]

# %%
y5 = d.head()

# %%
y5
# Out:
#                         Event  Athlete
# 0              100M Freestyle      148
# 1  100M Freestyle For Sailors        3
# 2             1200M Freestyle        3
# 3              400M Freestyle      144
# 4                        100M      142

# %% [markdown]
# ### 8. Which sport is having most female Gold Medalists? (Top 5)

# %%
x6 = df1[df1['Gender']=='Women']

# %%
x6
# Out:
#        Year      City          Sport           Discipline  \
# 417    1900     Paris           Golf                 Golf
# 641    1900     Paris         Tennis               Tennis
# 649    1900     Paris         Tennis               Tennis
# 710    1904  St Louis        Archery              Archery
# 713    1904  St Louis        Archery              Archery
# ...     ...       ...            ...                  ...
# 31081  2012    London  Weightlifting        Weightlifting
# 31097  2012    London      Wrestling  Wrestling Freestyle
# 31105  2012    London      Wrestling  Wrestling Freestyle
# 31113  2012    London      Wrestling  Wrestling Freestyle
# 31121  2012    London      Wrestling  Wrestling Freestyle
#
#                      Athlete Country Gender  \
# 417    ABBOTT, Margaret Ives     USA  Women
# 641        COOPER, Charlotte     GBR  Women
# 649        COOPER, Charlotte     GBR  Women
# 710    HOWELL, Matilda Scott     USA  Women
# ...

# %%
x6 = x6.drop(['Year','City','Discipline','Country','Gender','Event', 'Medal'], axis = 1)

# %%
x6
# Out:
#                Sport                Athlete
# 417             Golf  ABBOTT, Margaret Ives
# 641           Tennis      COOPER, Charlotte
# 649           Tennis      COOPER, Charlotte
# 710          Archery  HOWELL, Matilda Scott
# 713          Archery  HOWELL, Matilda Scott
# ...              ...                    ...
# 31081  Weightlifting  VALENTIN PEREZ, Lidia
# 31097      Wrestling          OBARA, Hitomi
# 31105      Wrestling         YOSHIDA, Saori
# 31113      Wrestling            ICHO, Kaori
# 31121      Wrestling     VOROBIEVA, Natalia
#
# [2788 rows x 2 columns]

# %%
f = x6.groupby(['Sport'], sort=False, as_index=False)['Athlete'].count()

# %%
f
# Out:
#                 Sport  Athlete
# 0                Golf        1
# 1              Tennis       38
# 2             Archery       39
# 3             Skating        4
# 4            Aquatics      589
# 5             Sailing       38
# 6             Fencing      108
# 7           Athletics      389
# 8          Gymnastics      268
# 9       Canoe / Kayak       76
# 10         Equestrian       51
# 11         Volleyball      166
# 12         Basketball      120
# 13           Handball      142
# 14             Rowing      217
# 15             Hockey      144
# 16            Cycling       45
# 17           Shooting       43
# 18       Table Tennis       23
# 19          Badminton       23
# 20               Judo       42
# 21           Football       86
# 22           Softball       60
# 23  Modern Pentathlon        4
# 24          Taekwondo       16
# 25          Triathlon        4
# 26      Weightlifting       28
# 27          Wrestling       12
# 28             Boxing        3
# ...
